# %%
import pandas as pd

# %%
flights = pd.read_csv("2008.csv")
flights.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 3  2008      1           3          4    926.0         930   1054.0
# 4  2008      1           3          4   1829.0        1755   1959.0
#
#    CRSArrTime UniqueCarrier  FlightNum        ...         TaxiIn  TaxiOut  \
# 0        2225            WN        335        ...            4.0      8.0
# 1        1000            WN       3231        ...            5.0     10.0
# 2         750            WN        448        ...            3.0     17.0
# 3        1100            WN       1746        ...            3.0      7.0
# 4        1925            WN       3920        ...            3.0     10.0
#
#    Cancelled  CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
flights = flights[(flights["Cancelled"] == 1) & (flights["CancellationCode"] == 'B')]
flights.count()
# Out:
# Year                 54904
# Month                54904
# DayofMonth           54904
# DayOfWeek            54904
# DepTime                498
# CRSDepTime           54904
# ArrTime                  0
# CRSArrTime           54904
# UniqueCarrier        54904
# FlightNum            54904
# TailNum              20948
# ActualElapsedTime        0
# CRSElapsedTime       54828
# AirTime                  0
# ArrDelay                 0
# DepDelay               498
# Origin               54904
# Dest                 54904
# Distance             54904
# TaxiIn                   0
# TaxiOut                220
# Cancelled            54904
# CancellationCode     54904
# Diverted             54904
# CarrierDelay             0
# WeatherDelay             0
# NASDelay                 0
# SecurityDelay            0
# LateAircraftDelay        0
# dtype: int64

# %%
flights = flights[['Year', 'Month', 'Origin', 'Dest', 'Cancelled']]
flights.head()
# Out:
#       Year  Month Origin Dest  Cancelled
# 2730  2008      1    BUR  SMF          1
# 3675  2008      1    LAS  RNO          1
# 3709  2008      1    LAS  SFO          1
# 3831  2008      1    LAX  RNO          1
# 3836  2008      1    LAX  SFO          1

# %%
airports = pd.read_csv('airports.csv')
airports[airports.iata == 'LAX']
# Out:
#      iata                    airport         city state country        lat  \
# 2039  LAX  Los Angeles International  Los Angeles    CA     USA  33.942536
#
#             long
# 2039 -118.408074

# %%
flights = pd.merge(flights, airports[['iata', 'lat', 'long']], left_on='Origin', right_on='iata')
flights.rename(columns={'lat': 'origin_lat', 'long': 'origin_long'}, inplace = True)
flights.drop('iata', 1, inplace=True)

# %%
flights = pd.merge(flights, airports[['iata', 'lat', 'long']], left_on='Dest', right_on='iata')
flights.rename(columns={'lat': 'dest_lat', 'long': 'dest_long'}, inplace = True)
flights.drop('iata', 1, inplace=True)

# %%
flights
# Out:
#        Year  Month Origin Dest  Cancelled  origin_lat  origin_long   dest_lat  \
# 0      2008      1    BUR  SMF          1   34.200619  -118.358497  38.695422
# 1      2008      1    BUR  SMF          1   34.200619  -118.358497  38.695422
# 2      2008      2    BUR  SMF          1   34.200619  -118.358497  38.695422
# 3      2008      8    BUR  SMF          1   34.200619  -118.358497  38.695422
# 4      2008      9    BUR  SMF          1   34.200619  -118.358497  38.695422
# 5      2008     11    BUR  SMF          1   34.200619  -118.358497  38.695422
# 6      2008     12    BUR  SMF          1   34.200619  -118.358497  38.695422
# 7      2008     12    BUR  SMF          1   34.200619  -118.358497  38.695422
# 8      2008      2    LAS  SMF          1   36.080361  -115.152333  38.695422
# 9      2008      2    LAS  SMF          1   36.080361  -115.152333  38.695422
# 10     2008      2    LAS  SMF          1   36.080361  -115.152333  38.695422
# ...

# %%
flights.to_csv('flights.csv')
